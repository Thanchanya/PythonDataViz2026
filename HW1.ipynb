# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanchanya/PythonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ธัณญ์ฌัณญา วงค์จันทร์

# %%
print('ID673020254-0')
# Out:
# ID673020254-0
